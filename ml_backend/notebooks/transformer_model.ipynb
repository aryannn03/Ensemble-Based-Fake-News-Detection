# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader, ConcatDataset, Subset
from transformers import (
    DistilBertTokenizerFast,
    DistilBertForSequenceClassification,
    DistilBertConfig,
    get_linear_schedule_with_warmup,
)
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.utils.class_weight import compute_class_weight
from joblib import dump
from tqdm.auto import tqdm

from preprocess import clean_text

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
true_df = pd.read_csv("True.csv")
fake_df = pd.read_csv("Fake.csv")

print("True.csv shape :", true_df.shape, "| columns:", true_df.columns.tolist())
print("Fake.csv shape :", fake_df.shape, "| columns:", fake_df.columns.tolist())

true_df["label"] = "real"
fake_df["label"] = "fake"

print("\nLabels assigned: True.csv → 'real' | Fake.csv → 'fake'")
# Out:
# True.csv shape : (21417, 4) | columns: ['title', 'text', 'subject', 'date']
# Fake.csv shape : (23481, 4) | columns: ['title', 'text', 'subject', 'date']
#
# Labels assigned: True.csv → 'real' | Fake.csv → 'fake'

# %%
def make_statement(df):
    title = df["title"].fillna("") if "title" in df.columns else pd.Series([""] * len(df), index=df.index)
    text  = df["text"].fillna("")  if "text"  in df.columns else pd.Series([""] * len(df), index=df.index)
    return (title + ". " + text).str.strip()

true_df["statement"] = make_statement(true_df)
fake_df["statement"] = make_statement(fake_df)

isot_df = pd.concat(
    [true_df[["statement", "label"]], fake_df[["statement", "label"]]],
    axis=0
).reset_index(drop=True)

isot_df = isot_df.dropna(subset=["statement", "label"]).reset_index(drop=True)
isot_df = isot_df.sample(frac=1.0, random_state=42).reset_index(drop=True)

print("ISOT combined shape:", isot_df.shape)
print(isot_df["label"].value_counts())
# Out:
# ISOT combined shape: (44898, 2)
# label
# fake    23481
# real    21417
# Name: count, dtype: int64

# %%
le = LabelEncoder()
le.fit(["fake", "real"])

print("le.classes_        :", le.classes_)
print("'fake' encodes to  :", le.transform(["fake"])[0])   # must be 0
print("'real' encodes to  :", le.transform(["real"])[0])   # must be 1
assert le.transform(["fake"])[0] == 0
assert le.transform(["real"])[0] == 1

num_labels = len(le.classes_)   # 2
print("\nEncoder verified: fake=0, real=1")
# Out:
# le.classes_        : ['fake' 'real']
# 'fake' encodes to  : 0
# 'real' encodes to  : 1
#
# Encoder verified: fake=0, real=1

# %%
train_df, temp_df = train_test_split(
    isot_df, test_size=0.30, random_state=42, stratify=isot_df["label"]
)
valid_df, test_df = train_test_split(
    temp_df, test_size=0.50, random_state=42, stratify=temp_df["label"]
)

train_df = train_df.copy().reset_index(drop=True)
valid_df = valid_df.copy().reset_index(drop=True)
test_df  = test_df.copy().reset_index(drop=True)

print("Train:", train_df.shape, "| Valid:", valid_df.shape, "| Test:", test_df.shape)
print("Train label dist:")
print(train_df["label"].value_counts())
# Out:
# Train: (31428, 2) | Valid: (6735, 2) | Test: (6735, 2)
# Train label dist:
# label
# fake    16436
# real    14992
# Name: count, dtype: int64

# %%
# Clean text
train_df["text_clean"] = train_df["statement"].astype(str).apply(clean_text)
valid_df["text_clean"] = valid_df["statement"].astype(str).apply(clean_text)
test_df["text_clean"]  = test_df["statement"].astype(str).apply(clean_text)

# Encode labels
y_train = le.transform(train_df["label"])
y_valid = le.transform(valid_df["label"])
y_test  = le.transform(test_df["label"])

print("y_train unique:", np.unique(y_train, return_counts=True))
print("y_valid unique:", np.unique(y_valid, return_counts=True))
print("Sample — label='real' → encoded:", le.transform(["real"])[0])
print("Sample — label='fake' → encoded:", le.transform(["fake"])[0])
# Out:
# y_train unique: (array([0, 1]), array([16436, 14992]))
# y_valid unique: (array([0, 1]), array([3522, 3213]))
# Sample — label='real' → encoded: 1
# Sample — label='fake' → encoded: 0

# %%
MAX_LEN    = 256
BATCH_SIZE = 8

tokenizer = DistilBertTokenizerFast.from_pretrained("distilbert-base-uncased")

class NewsDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts     = list(texts)
        self.labels    = list(labels)
        self.tokenizer = tokenizer
        self.max_len   = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            str(self.texts[idx]),
            add_special_tokens=True,
            truncation=True,
            max_length=self.max_len,
            padding="max_length",
            return_attention_mask=True,
            return_tensors="pt"
        )
        return {
            "input_ids":      encoding["input_ids"].flatten(),
            "attention_mask": encoding["attention_mask"].flatten(),
            "labels":         torch.tensor(self.labels[idx], dtype=torch.long)
        }

train_dataset = NewsDataset(train_df["text_clean"], y_train, tokenizer, MAX_LEN)
valid_dataset = NewsDataset(valid_df["text_clean"], y_valid, tokenizer, MAX_LEN)
test_dataset  = NewsDataset(test_df["text_clean"],  y_test,  tokenizer, MAX_LEN)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE)

print("Train / Valid / Test batches:", len(train_loader), len(valid_loader), len(test_loader))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# [Widget: bcade97bb2ea408a8b247c2e55e28400]
# [Widget: 5873a58ec349414389265f308d477b34]
# [Widget: 5a1c35411c5e4b3cb25aae088b56ecf1]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Train / Valid / Test batches: 3929 842 842

# %%
BASE_MODEL = "distilbert-base-uncased"

config = DistilBertConfig.from_pretrained(BASE_MODEL, num_labels=num_labels)
model  = DistilBertForSequenceClassification.from_pretrained(BASE_MODEL, config=config)
model.to(device)

# Class weights for imbalanced training
class_weights_isot = compute_class_weight("balanced", classes=np.unique(y_train), y=y_train)
class_weights_isot = torch.tensor(class_weights_isot, dtype=torch.float).to(device)
print("ISOT class weights:", class_weights_isot)

EPOCHS_ISOT = 4
LR_ISOT     = 3e-5

optimizer_isot = optim.Adam(model.parameters(), lr=LR_ISOT)
steps_isot     = EPOCHS_ISOT * len(train_loader)
scheduler_isot = get_linear_schedule_with_warmup(
    optimizer_isot,
    num_warmup_steps=int(0.10 * steps_isot),
    num_training_steps=steps_isot
)
print(f"Total ISOT training steps: {steps_isot}")
# Out:
# [Widget: 63f01a2515f94ee2b6df25021d3c0e8d]
# [Widget: 519fce07b13349a48847128be856d7f3]
# [Widget: 3e51260a6a38440fa6614e4188c07e4e]
# DistilBertForSequenceClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# vocab_projector.bias    | UNEXPECTED |
# vocab_layer_norm.bias   | UNEXPECTED |
# pre_classifier.bias     | MISSING    |
# classifier.bias         | MISSING    |
# classifier.weight       | MISSING    |
# pre_classifier.weight   | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ISOT class weights: tensor([0.9561, 1.0482], device='cuda:0')
# ...

# %%
def run_train_epoch(model, loader, optimizer, scheduler, device, class_weights):
    model.train()
    total_loss = 0.0
    for batch in tqdm(loader, desc="Training", leave=False):
        optimizer.zero_grad()
        ids    = batch["input_ids"].to(device)
        mask   = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)
        logits = model(input_ids=ids, attention_mask=mask).logits
        loss   = F.cross_entropy(logits, labels, weight=class_weights)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()
        total_loss += loss.item()
    return total_loss / len(loader)


def run_eval(model, loader, device, label_encoder, desc="Evaluating"):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in tqdm(loader, desc=desc, leave=False):
            ids    = batch["input_ids"].to(device)
            mask   = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)
            logits = model(input_ids=ids, attention_mask=mask).logits
            preds  = torch.argmax(logits, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    acc    = accuracy_score(all_labels, all_preds)
    report = classification_report(
        all_labels, all_preds,
        target_names=label_encoder.classes_,   # ['fake', 'real']
        zero_division=0
    )
    return acc, report

# %%
best_val_acc_isot  = 0.0
best_state_isot    = None

for epoch in range(EPOCHS_ISOT):
    print(f"\n── ISOT Epoch {epoch+1}/{EPOCHS_ISOT} ──")
    tr_loss = run_train_epoch(model, train_loader, optimizer_isot, scheduler_isot,
                              device, class_weights_isot)
    val_acc, val_rep = run_eval(model, valid_loader, device, le, desc="ISOT Val")

    print(f"  Train Loss : {tr_loss:.4f}")
    print(f"  Val Acc    : {val_acc*100:.2f}%")
    print(val_rep)

    if val_acc > best_val_acc_isot:
        best_val_acc_isot = val_acc
        best_state_isot   = {k: v.clone() for k, v in model.state_dict().items()}
        print(f"  New best ISOT model  (val acc = {best_val_acc_isot*100:.2f}%)")

model.load_state_dict(best_state_isot)
print(f"\nBest ISOT model loaded  (val acc = {best_val_acc_isot*100:.2f}%)")
# Out:
# ── ISOT Epoch 1/4 ──
# [Widget: c74018fb5faa4e299a283cfef866aaf3]
# [Widget: 07291d8371d2475f82d05f118780100c]
#   Train Loss : 0.0524
#   Val Acc    : 99.91%
#               precision    recall  f1-score   support
#
#         fake       1.00      1.00      1.00      3522
#         real       1.00      1.00      1.00      3213
#
#     accuracy                           1.00      6735
#    macro avg       1.00      1.00      1.00      6735
# weighted avg       1.00      1.00      1.00      6735
#
#   New best ISOT model  (val acc = 99.91%)
#
# ── ISOT Epoch 2/4 ──
# [Widget: c09dd64e532147058b08cfee80b15e25]
# [Widget: d71fb60ac29f482883295d9b35ddae20]
#   Train Loss : 0.0080
#   Val Acc    : 99.93%
#               precision    recall  f1-score   support
#
#         fake       1.00      1.00      1.00      3522
#         real       1.00      1.00      1.00      3213
#
#     accuracy                           1.00      6735
#    macro avg       1.00      1.00      1.00      6735
# ...

# %%
isot_test_acc, isot_test_rep = run_eval(model, test_loader, device, le, desc="ISOT Test")
print(f"\nISOT Test Accuracy  : {isot_test_acc*100:.2f}%")
print(isot_test_rep)
# Out:
# [Widget: 9dfcfe0c88944ab9ac4cd12fbcd6d086]
# ISOT Test Accuracy  : 99.97%
#               precision    recall  f1-score   support
#
#         fake       1.00      1.00      1.00      3523
#         real       1.00      1.00      1.00      3212
#
#     accuracy                           1.00      6735
#    macro avg       1.00      1.00      1.00      6735
# weighted avg       1.00      1.00      1.00      6735

# %%
wel_df = pd.read_csv("WELFake_Dataset.csv")
print("WELFake raw shape  :", wel_df.shape)
print("Columns            :", wel_df.columns.tolist())
print("label dtype        :", wel_df["label"].dtype)
print("Unique label values:", sorted(wel_df["label"].dropna().unique().tolist()))
print("\nNull counts:")
print(wel_df.isnull().sum())
# Out:
# WELFake raw shape  : (72134, 4)
# Columns            : ['Unnamed: 0', 'title', 'text', 'label']
# label dtype        : int64
# Unique label values: [0, 1]
#
# Null counts:
# Unnamed: 0      0
# title         558
# text           39
# label           0
# dtype: int64

# %%
wel_df = wel_df.dropna(subset=["text"]).reset_index(drop=True)
print("After dropping null text rows:", wel_df.shape)

WEL_INT_TO_STR = {0: "real", 1: "fake"}

wel_df["label_str"] = wel_df["label"].map(WEL_INT_TO_STR)

n_unmapped = wel_df["label_str"].isna().sum()
assert n_unmapped == 0, f"{n_unmapped} rows could not be mapped — check raw label values!"
print("\nWELFake label_str distribution:")
print(wel_df["label_str"].value_counts())

wel_df["label_enc"] = le.transform(wel_df["label_str"])
print("\nWELFake label_enc distribution (after le.transform):")
print(pd.Series(wel_df["label_enc"]).value_counts())

assert set(wel_df["label_enc"].unique()) == {0, 1}, "Missing a class after encoding!"
print("\nWELFake label encoding verified and consistent with ISOT encoder.")
# Out:
# After dropping null text rows: (72095, 4)
#
# WELFake label_str distribution:
# label_str
# fake    37067
# real    35028
# Name: count, dtype: int64
#
# WELFake label_enc distribution (after le.transform):
# label_enc
# 0    37067
# 1    35028
# Name: count, dtype: int64
#
# WELFake label encoding verified and consistent with ISOT encoder.

# %%
wel_df["statement"] = make_statement(wel_df)

wel_df["text_clean"] = wel_df["statement"].astype(str).apply(clean_text)

drop_cols = [c for c in ["Unnamed: 0", "title", "text", "statement", "label", "label_str"] if c in wel_df.columns]
wel_df.drop(columns=drop_cols, inplace=True)

print("WELFake final columns:", wel_df.columns.tolist())
print("Shape:", wel_df.shape)
print(wel_df.head(3))
# Out:
# WELFake final columns: ['label_enc', 'text_clean']
# Shape: (72095, 2)
#    label_enc                                         text_clean
# 0          0  law enforcement on high alert following threat...
# 1          0      did they post their votes for hillary already
# 2          0  unbelievable obama s attorney general says mos...

# %%
train_wel, val_wel = train_test_split(
    wel_df, test_size=0.20, random_state=42, stratify=wel_df["label_enc"]
)
train_wel = train_wel.reset_index(drop=True)
val_wel   = val_wel.reset_index(drop=True)

y_train_wel = train_wel["label_enc"].values
y_val_wel   = val_wel["label_enc"].values

print("WELFake train:", train_wel.shape, "| val:", val_wel.shape)
print("Train dist:", np.unique(y_train_wel, return_counts=True))
# Out:
# WELFake train: (57676, 2) | val: (14419, 2)
# Train dist: (array([0, 1]), array([29654, 28022]))

# %%
train_dataset_wel = NewsDataset(train_wel["text_clean"], y_train_wel, tokenizer, MAX_LEN)
val_dataset_wel   = NewsDataset(val_wel["text_clean"],   y_val_wel,   tokenizer, MAX_LEN)

REPLAY_FRACTION = 0.20
n_replay        = int(len(train_dataset_wel) * REPLAY_FRACTION)
replay_idx      = np.random.default_rng(42).choice(len(train_dataset), size=n_replay, replace=False)
replay_subset   = Subset(train_dataset, replay_idx)

mixed_dataset   = ConcatDataset([train_dataset_wel, replay_subset])
train_loader_ft = DataLoader(mixed_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader_ft   = DataLoader(val_dataset_wel, batch_size=BATCH_SIZE)

print(f"WELFake train    : {len(train_dataset_wel):,}")
print(f"ISOT replay      : {len(replay_subset):,}")
print(f"Mixed total      : {len(mixed_dataset):,}")
print(f"Fine-tune batches: {len(train_loader_ft):,}")
# Out:
# WELFake train    : 57,676
# ISOT replay      : 11,535
# Mixed total      : 69,211
# Fine-tune batches: 8,652

# %%
FREEZE_LAYERS = 4   # freeze bottom 4 of 6 transformer layers

for param in model.distilbert.embeddings.parameters():
    param.requires_grad = False
for i in range(FREEZE_LAYERS):
    for param in model.distilbert.transformer.layer[i].parameters():
        param.requires_grad = False

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total     = sum(p.numel() for p in model.parameters())
print(f"Trainable params: {trainable:,} / {total:,}  ({100*trainable/total:.1f}%)")
print("(Only layers 4–5 + classifier head will be updated)")
# Out:
# Trainable params: 14,767,874 / 66,955,010  (22.1%)
# (Only layers 4–5 + classifier head will be updated)

# %%
EPOCHS_FT = 3
LR_FT     = 4e-6

optimizer_ft = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=LR_FT,
    weight_decay=0.01
)
steps_ft     = EPOCHS_FT * len(train_loader_ft)
scheduler_ft = get_linear_schedule_with_warmup(
    optimizer_ft,
    num_warmup_steps=int(0.20 * steps_ft),
    num_training_steps=steps_ft
)

y_replay_labels = y_train[replay_idx]
y_mixed_all     = np.concatenate([y_train_wel, y_replay_labels])
cw_ft           = compute_class_weight("balanced", classes=np.unique(y_mixed_all), y=y_mixed_all)
class_weights_ft = torch.tensor(cw_ft, dtype=torch.float).to(device)
print("Fine-tune class weights (mixed):", class_weights_ft)
print(f"Fine-tune training steps: {steps_ft}")
# Out:
# Fine-tune class weights (mixed): tensor([0.9698, 1.0322], device='cuda:0')
# Fine-tune training steps: 25956

# %%
best_combined  = 0.0
best_state_ft  = None

for epoch in range(EPOCHS_FT):
    print(f"\n── Fine-tune Epoch {epoch+1}/{EPOCHS_FT} ──")
    tr_loss = run_train_epoch(model, train_loader_ft, optimizer_ft, scheduler_ft,
                              device, class_weights_ft)

    # Evaluate on WELFake val
    wel_val_acc, wel_val_rep = run_eval(model, val_loader_ft, device, le, desc="WELFake Val")
    # Evaluate on ISOT val — monitors forgetting
    isot_val_acc, _          = run_eval(model, valid_loader,  device, le, desc="ISOT Val")

    print(f"  Train Loss        : {tr_loss:.4f}")
    print(f"  WELFake Val Acc   : {wel_val_acc*100:.2f}%")
    print(f"  ISOT    Val Acc   : {isot_val_acc*100:.2f}%")
    print(wel_val_rep)

    # Model selection: harmonic mean of both accuracies
    combined = (2 * wel_val_acc * isot_val_acc) / (wel_val_acc + isot_val_acc + 1e-9)
    print(f"  Harmonic mean     : {combined:.4f}")

    if combined > best_combined:
        best_combined = combined
        best_state_ft = {k: v.clone() for k, v in model.state_dict().items()}
        print("  Best combined model saved!")

model.load_state_dict(best_state_ft)
print(f"\nBest fine-tuned model loaded  (harmonic mean = {best_combined:.4f})")
# Out:
# ── Fine-tune Epoch 1/3 ──
# [Widget: 5f910695f87146229d1aa8db3f2b5694]
# [Widget: 9cb20ac426c048ecbcdab24a56254efd]
# [Widget: 67d949e1b64e426f914a7baac82c12b3]
#   Train Loss        : 0.1480
#   WELFake Val Acc   : 95.33%
#   ISOT    Val Acc   : 98.43%
#               precision    recall  f1-score   support
#
#         fake       0.95      0.96      0.96      7413
#         real       0.96      0.94      0.95      7006
#
#     accuracy                           0.95     14419
#    macro avg       0.95      0.95      0.95     14419
# weighted avg       0.95      0.95      0.95     14419
#
#   Harmonic mean     : 0.9685
#   Best combined model saved!
#
# ── Fine-tune Epoch 2/3 ──
# [Widget: 63d814331f2648b2a323e616bce6c13d]
# [Widget: bd0f313b868a490385d795e4413c7366]
# [Widget: 3501ecb1ab924db190b1753ed6bc0a4f]
#   Train Loss        : 0.1400
#   WELFake Val Acc   : 95.49%
#   ISOT    Val Acc   : 98.84%
#               precision    recall  f1-score   support
#
# ...

# %%
isot_final_acc, isot_final_rep = run_eval(model, test_loader, device, le, desc="ISOT Test")
print(f" ISOT  Test Accuracy (after fine-tuning): {isot_final_acc*100:.2f}%")
print(isot_final_rep)
# Out:
# [Widget: 2a0df794d5524b648bcdaf47a74a507c]
#  ISOT  Test Accuracy (after fine-tuning): 98.98%
#               precision    recall  f1-score   support
#
#         fake       1.00      0.98      0.99      3523
#         real       0.98      1.00      0.99      3212
#
#     accuracy                           0.99      6735
#    macro avg       0.99      0.99      0.99      6735
# weighted avg       0.99      0.99      0.99      6735

# %%
wel_test_dataset = NewsDataset(wel_df["text_clean"], wel_df["label_enc"].values, tokenizer, MAX_LEN)
wel_test_loader  = DataLoader(wel_test_dataset, batch_size=BATCH_SIZE)

wel_final_acc, wel_final_rep = run_eval(model, wel_test_loader, device, le, desc="WELFake Test")
print(f" WELFake Test Accuracy (after fine-tuning): {wel_final_acc*100:.2f}%")
print(wel_final_rep)
# Out:
# [Widget: 5438f7c44edf4063a600beb02a161a9f]
#  WELFake Test Accuracy (after fine-tuning): 95.48%
#               precision    recall  f1-score   support
#
#         fake       0.94      0.98      0.96     37067
#         real       0.97      0.93      0.95     35028
#
#     accuracy                           0.95     72095
#    macro avg       0.96      0.95      0.95     72095
# weighted avg       0.96      0.95      0.95     72095

# %%
hm = (2 * isot_final_acc * wel_final_acc) / (isot_final_acc + wel_final_acc + 1e-9)

print("=" * 50)
print("         FINAL RESULTS SUMMARY")
print("=" * 50)
print(f"  ISOT   Test Accuracy : {isot_final_acc*100:.2f}%")
print(f"  WELFake Test Accuracy: {wel_final_acc*100:.2f}%")
print(f"  Harmonic Mean        : {hm*100:.2f}%")
print("=" * 50)
# Out:
# ...
#          FINAL RESULTS SUMMARY
# ...
#   ISOT   Test Accuracy : 98.98%
#   WELFake Test Accuracy: 95.48%
#   Harmonic Mean        : 97.20%
# ...

# %%
save_obj = {
    "model_state_dict" : model.state_dict(),
    "model_name"       : BASE_MODEL,
    "num_labels"       : num_labels,
    "max_len"          : MAX_LEN,
    "label_encoder"    : le,
    "label_classes"    : list(le.classes_),          # ['fake', 'real']
    "welfake_int_map"  : {0: "real", 1: "fake"},     # saved for reference
}
dump(save_obj, "transformer_model.pkl")
torch.save(model.state_dict(),"transformer_model.pt")
print("Model saved → transformer_model.pkl & transformer_model.pt")
# Out:
# Model saved → transformer_model.pkl & transformer_model.pt
